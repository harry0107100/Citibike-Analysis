# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('JC-201808-citibike-tripdata.csv')
# df = df.drop(['Unnamed: 0', 'Unnamed: 1'], axis = 1)
df_copy = df
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44432 entries, 0 to 44431
# Data columns (total 15 columns):
# tripduration               44432 non-null int64
# starttime                  44432 non-null object
# stoptime                   44432 non-null object
# start station id           44432 non-null int64
# start station name         44432 non-null object
# start station latitude     44432 non-null float64
# start station longitude    44432 non-null float64
# end station id             44432 non-null int64
# end station name           44432 non-null object
# end station latitude       44432 non-null float64
# end station longitude      44432 non-null float64
# bikeid                     44432 non-null int64
# usertype                   44432 non-null object
# birth year                 44432 non-null int64
# gender                     44432 non-null int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 5.1+ MB

# %%
df = df.drop(df.index[(df['tripduration'] > 10800)])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44323 entries, 0 to 44431
# Data columns (total 15 columns):
# tripduration               44323 non-null int64
# starttime                  44323 non-null object
# stoptime                   44323 non-null object
# start station id           44323 non-null int64
# start station name         44323 non-null object
# start station latitude     44323 non-null float64
# start station longitude    44323 non-null float64
# end station id             44323 non-null int64
# end station name           44323 non-null object
# end station latitude       44323 non-null float64
# end station longitude      44323 non-null float64
# bikeid                     44323 non-null int64
# usertype                   44323 non-null object
# birth year                 44323 non-null int64
# gender                     44323 non-null int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 5.4+ MB

# %%
df.index[(df['tripduration']> 2700)]
# Out:
# Int64Index([  195,   196,   197,   343,   844,   916,   937,   953,  1044,
#              1045,
#             ...
#             43925, 43926, 44031, 44122, 44230, 44386, 44387, 44388, 44402,
#             44404],
#            dtype='int64', length=669)

# %%
df_sample = df.sample(frac = 0.1, random_state = 0)

# %%
df=df.drop(['starttime'], axis = 1)
df=df.drop(['stoptime'], axis = 1)
df=df.drop(['start station name'], axis = 1)
df=df.drop(['end station name'], axis = 1)
df=df.drop(['start station latitude'], axis = 1)
df=df.drop(['end station latitude'], axis = 1)
df=df.drop(['usertype'], axis = 1)
df=df.drop(['birth year'], axis = 1)
df=df.drop(['gender'], axis = 1)

# %%
df
# Out:
#        tripduration  start station id  start station longitude  \
# 0               903              3183               -74.033459
# 1                78              3183               -74.033459
# 2               405              3183               -74.033459
# 3               155              3183               -74.033459
# 4               453              3183               -74.033459
# 5               336              3183               -74.033459
# 6               462              3183               -74.033459
# 7               346              3183               -74.033459
# 8               649              3183               -74.033459
# 9               298              3183               -74.033459
# 10              268              3183               -74.033459
# 11              299              3183               -74.033459
# 12              495              3183               -74.033459
# 13              287              3183               -74.033459
# ...
